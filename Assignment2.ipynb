# %%
import pandas as pd 
import numpy as np

# %%
df_gdp = pd.read_csv("https://raw.githubusercontent.com/Accelerate-AI/Data-Science-Global-Bootcamp/main/01%20Python/gapminder.csv")

# %%
df_gdp
# Out:
#      population  fertility   HIV        CO2  BMI_male      GDP  BMI_female  \
# 0    34811059.0       2.73   0.1   3.328945  24.59620  12314.0    129.9049
# 1    19842251.0       6.43   2.0   1.474353  22.25083   7103.0    130.1247
# 2    40381860.0       2.24   0.5   4.785170  27.50170  14646.0    118.8915
# 3     2975029.0       1.40   0.1   1.804106  25.35542   7383.0    132.8108
# 4    21370348.0       1.96   0.1  18.016313  27.56373  41312.0    117.3755
# ..          ...        ...   ...        ...       ...      ...         ...
# 134   3350832.0       2.11   0.5   2.489764  26.39123  15317.0    124.2604
# 135  26952719.0       2.46   0.1   4.476669  25.32054   3733.0    124.3462
# 136  86589342.0       1.86   0.4   1.479347  20.91630   4085.0    121.9367
# 137  13114579.0       5.88  13.6   0.148982  20.68321   3039.0    132.4493
# 138  13495462.0       3.85  15.1   0.654323  22.02660   1286.0    131.9745
#
#      life  child_mortality                      Region
# ...

# %%
df_gdp.shape
# Out:
# (139, 10)

# %%
df_gdp.describe()
# Out:
#          population   fertility         HIV         CO2    BMI_male  \
# count  1.390000e+02  139.000000  139.000000  139.000000  139.000000
# mean   3.549977e+07    3.005108    1.915612    4.459874   24.623054
# std    1.095121e+08    1.615354    4.408974    6.268349    2.209368
# min    2.773150e+05    1.280000    0.060000    0.008618   20.397420
# 25%    3.752776e+06    1.810000    0.100000    0.496190   22.448135
# 50%    9.705130e+06    2.410000    0.400000    2.223796   25.156990
# 75%    2.791973e+07    4.095000    1.300000    6.589156   26.497575
# max    1.197070e+09    7.590000   25.900000   48.702062   28.456980
#
#                  GDP  BMI_female        life  child_mortality
# count     139.000000  139.000000  139.000000       139.000000
# mean    16638.784173  126.701914   69.602878        45.097122
# std     19207.299083    4.471997    9.122189        45.724667
# min       588.000000  117.375500   45.200000         2.700000
# ...

# %%
df_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   population       139 non-null    float64
#  1   fertility        139 non-null    float64
#  2   HIV              139 non-null    float64
#  3   CO2              139 non-null    float64
#  4   BMI_male         139 non-null    float64
#  5   GDP              139 non-null    float64
#  6   BMI_female       139 non-null    float64
#  7   life             139 non-null    float64
#  8   child_mortality  139 non-null    float64
#  9   Region           139 non-null    object
# dtypes: float64(9), object(1)
# memory usage: 11.0+ KB

# %%
df_gdp['Region'].value_counts()
# Out:
# Europe & Central Asia         41
# Sub-Saharan Africa            40
# America                       27
# East Asia & Pacific           14
# Middle East & North Africa    10
# South Asia                     7
# Name: Region, dtype: int64

# %%
df_gdp['Region'].unique()
# Out:
# array(['Middle East & North Africa', 'Sub-Saharan Africa', 'America',
#        'Europe & Central Asia', 'East Asia & Pacific', 'South Asia'],
#       dtype=object)

# %% [markdown]
# #  Q1. The “Gapminder” dataset contains the health, life expectancy and GDP information for multiple countries categorized by “Region”. Use encoding techniques (One hot encoding and Label encoding) for the category column “Region” and provide your solution in the form of upyter notebook file. Explain which encoding technique should you use and why?

# %%
"""  Nominal Encoding using One Hot encoding as Region column is a Nominal Variable, Label encoding is applied on 
combination of nominal and ordinal data where we can arrange data in an order hecne not used here. """
ohe_gdp = pd.get_dummies(df_gdp['Region'])

# %%
ohe_gdp
# Out:
#      America  East Asia & Pacific  Europe & Central Asia  \
# 0          0                    0                      0
# 1          0                    0                      0
# 2          1                    0                      0
# 3          0                    0                      1
# 4          0                    1                      0
# ..       ...                  ...                    ...
# 134        1                    0                      0
# 135        0                    0                      1
# 136        0                    1                      0
# 137        0                    0                      0
# 138        0                    0                      0
#
#      Middle East & North Africa  South Asia  Sub-Saharan Africa
# 0                             1           0                   0
# 1                             0           0                   1
# 2                             0           0                   0
# ...

# %%
gdp_ohe = pd.concat([df_gdp,ohe_gdp],axis='columns')

# %%
gdp_ohe
# Out:
#      population  fertility   HIV        CO2  BMI_male      GDP  BMI_female  \
# 0    34811059.0       2.73   0.1   3.328945  24.59620  12314.0    129.9049
# 1    19842251.0       6.43   2.0   1.474353  22.25083   7103.0    130.1247
# 2    40381860.0       2.24   0.5   4.785170  27.50170  14646.0    118.8915
# 3     2975029.0       1.40   0.1   1.804106  25.35542   7383.0    132.8108
# 4    21370348.0       1.96   0.1  18.016313  27.56373  41312.0    117.3755
# ..          ...        ...   ...        ...       ...      ...         ...
# 134   3350832.0       2.11   0.5   2.489764  26.39123  15317.0    124.2604
# 135  26952719.0       2.46   0.1   4.476669  25.32054   3733.0    124.3462
# 136  86589342.0       1.86   0.4   1.479347  20.91630   4085.0    121.9367
# 137  13114579.0       5.88  13.6   0.148982  20.68321   3039.0    132.4493
# 138  13495462.0       3.85  15.1   0.654323  22.02660   1286.0    131.9745
#
#      life  child_mortality                      Region  America  \
# ...

# %%
gdp_ohe.drop(['Region','Sub-Saharan Africa'],axis = 'columns', inplace= True)
# dropped last one hot encoded colum to avoid dummy variable trap

# %%
gdp_ohe
# Out:
#      population  fertility   HIV        CO2  BMI_male      GDP  BMI_female  \
# 0    34811059.0       2.73   0.1   3.328945  24.59620  12314.0    129.9049
# 1    19842251.0       6.43   2.0   1.474353  22.25083   7103.0    130.1247
# 2    40381860.0       2.24   0.5   4.785170  27.50170  14646.0    118.8915
# 3     2975029.0       1.40   0.1   1.804106  25.35542   7383.0    132.8108
# 4    21370348.0       1.96   0.1  18.016313  27.56373  41312.0    117.3755
# ..          ...        ...   ...        ...       ...      ...         ...
# 134   3350832.0       2.11   0.5   2.489764  26.39123  15317.0    124.2604
# 135  26952719.0       2.46   0.1   4.476669  25.32054   3733.0    124.3462
# 136  86589342.0       1.86   0.4   1.479347  20.91630   4085.0    121.9367
# 137  13114579.0       5.88  13.6   0.148982  20.68321   3039.0    132.4493
# 138  13495462.0       3.85  15.1   0.654323  22.02660   1286.0    131.9745
#
#      life  child_mortality  America  East Asia & Pacific  \
# ...

# %% [markdown]
# For Q2 and Q3, please follow below description: Let's refer free “Wine” Dataset that is
# deposited on the UCI machine learning repository. You can refer to GitHub for this -

# %%
df_wine = pd.read_csv("https://raw.githubusercontent.com/Accelerate-AI/Data-Science-Global-Bootcamp/main/01%20Python/wine_data_UCI.csv")

# %%
df_wine.head()
# Out:
#    quality  Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  \
# 0        1    14.23       1.71  2.43               15.6        127
# 1        1    13.20       1.78  2.14               11.2        100
# 2        1    13.16       2.36  2.67               18.6        101
# 3        1    14.37       1.95  2.50               16.8        113
# 4        1    13.24       2.59  2.87               21.0        118
#
#    Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color_intensity   Hue  0D280_0D315_of_diluted_wines  Proline
# 0             5.64  1.04                          3.92     1065
# ...

# %% [markdown]
# The Wine dataset consists of 3 different classes/qualities where each row corresponds to a
# particular wine sample. The "quality" features indicate the class/quality of wine and it is
# represented as (1, 2, 3) and rest of the columns correspond to 13 different attributes
# (features).
# Consider the features - the wine quality i.e. "quality", "Alcohol" (percent/volume) and
# "Malicacid" (g/l).

# %%
wine_scale = df_wine[['quality','Alcohol','Malicacid']]

# %%
wine_scale
# Out:
#      quality  Alcohol  Malicacid
# 0          1    14.23       1.71
# 1          1    13.20       1.78
# 2          1    13.16       2.36
# 3          1    14.37       1.95
# 4          1    13.24       2.59
# ..       ...      ...        ...
# 173        3    13.71       5.65
# 174        3    13.40       3.91
# 175        3    13.27       4.28
# 176        3    13.17       2.59
# 177        3    14.13       4.10
#
# [178 rows x 3 columns]

# %% [markdown]
# # Q2: Do you think feature scaling is required? If yes - Why, If no - why?

# %% [markdown]
#  Yes,when we have feature of different magnitute and units feature scaling is required. Here we have 3 different features
# quality,Alcohol,Malicacid.

# %% [markdown]
# .

# %% [markdown]
# # Q3: If you feel feature scaling is required, then perform Standardization and Normalization and provide your result. What is the difference you observe between these two methods?

# %%
#Standardization
from sklearn.preprocessing import StandardScaler

# %%
scaling = StandardScaler()

# %%
scaling.fit_transform(wine_scale[['Alcohol','Malicacid']])
# Out:
# array([[ 1.51861254, -0.5622498 ],
#        [ 0.24628963, -0.49941338],
#        [ 0.19687903,  0.02123125],
#        [ 1.69154964, -0.34681064],
#        [ 0.29570023,  0.22769377],
#        [ 1.48155459, -0.51736664],
#        [ 1.71625494, -0.4186237 ],
#        [ 1.3086175 , -0.16727801],
#        [ 2.25977152, -0.62508622],
#        [ 1.0615645 , -0.88540853],
#        [ 1.3580281 , -0.15830138],
#        [ 1.38273339, -0.76871232],
#        [ 0.92568536, -0.54429654],
#        [ 2.16095032, -0.54429654],
#        [ 1.70390229, -0.4186237 ],
#        [ 0.77745356, -0.47248348],
#        [ 1.60508109, -0.37374054],
#        [ 1.02450655, -0.68792264],
#        [ 1.46920194, -0.66996938],
#        [ 0.78980621,  0.68550197],
#        [ 1.3086175 , -0.63406285],
#        [-0.08723191,  1.31386618],
#        [ 0.87627476, -0.42760033],
#        [-0.18605311, -0.66099274],
#        [ 0.61686912, -0.47248348],
#        [ 0.06099988, -0.25704433],
#        [ 0.48098997, -0.50839001],
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
#Normalization
scaling = MinMaxScaler()

# %%
scaling.fit_transform(wine_scale[['Alcohol','Malicacid']])
# Out:
# array([[0.84210526, 0.1916996 ],
#        [0.57105263, 0.2055336 ],
#        [0.56052632, 0.3201581 ],
#        [0.87894737, 0.23913043],
#        [0.58157895, 0.36561265],
#        [0.83421053, 0.20158103],
#        [0.88421053, 0.22332016],
#        [0.79736842, 0.27865613],
#        [1.        , 0.17786561],
#        [0.74473684, 0.12055336],
#        [0.80789474, 0.28063241],
#        [0.81315789, 0.14624506],
#        [0.71578947, 0.19565217],
#        [0.97894737, 0.19565217],
#        [0.88157895, 0.22332016],
#        [0.68421053, 0.21146245],
#        [0.86052632, 0.23320158],
#        [0.73684211, 0.16403162],
#        [0.83157895, 0.16798419],
#        [0.68684211, 0.46640316],
#        [0.79736842, 0.17588933],
#        [0.5       , 0.60474308],
#        [0.70526316, 0.22134387],
#        [0.47894737, 0.16996047],
#        [0.65      , 0.21146245],
#        [0.53157895, 0.25889328],
#        [0.62105263, 0.20355731],
#        [0.59736842, 0.19367589],
# ...

# %% [markdown]
# # Standardization VS Normalization

# %% [markdown]
# - Standardization scale down feature based standard normal distribution where mean is 0 and sd is 1
# - Normalization scale down feature between 0 to 1

# %% [markdown]
# # Q4: Facebook has a content team that labels pieces of content on the platform as spam or not spam. 90% of them are diligent raters and will correctly label 95% of the time. The remaining 10% are non-diligent raters and will label 50% of the content incorrectly. Assume the pieces of content are labeled independently from one another, for every rater. Given that a piece has been rated as non-spam, what is the probability that is it actually non-spam?

# %% [markdown]
# P(XA) = 0.9, P(XB)=0.1
# P(Y/XA) =0.95, P(Y/XB)=0.2
#
#
# P(Y)= (0.95)(0.9)+(0.2)(0.1)=0.875

# %% [markdown]
# # Q5: If the probability of seeing a car on the highway in 30 minutes is 0.95, what is the probability of seeing a car on the highway in 10 minutes? (Assume a constant default probability)

# %% [markdown]
# Let p is a probability to see a car in 10 minutes.
# Then (1-p) is probability NOT to see a car in 10 minutes.
# Then probability NOT to see a car in 30 minutes is (1-p)*(1-p)*(1-p).
# (1-p)^3 == 0.05
# So p = 1-0.05^(1/3)= 0.63

# %% [markdown]
# # Q6: A machine produces items of which 1% at random are defective. How many items can be packed in a box while keeping the chance of one or more defectives in the box to be no more than 0.5? What are the expected value and standard deviation of the number of defectives in a box of that size?

# %% [markdown]
# Let X be the number of defectives when n items are packed into a box.
#
# P(X = 0) = (0.99)n
#
# P(X ≥ 1) = 1 – P(X = 0) = 1 − (0.99)n
#
# P(X ≥ 1) < 0.5
#
# 1 − (0.99)n < 0.5
#
# n < log 0.5/ log 0.99 = 68.97
#
# n = 68
#
# The expected value and standard deviation of X when n = 68 are 0.68 and √0.68 × 0.99 = 0.8205.
